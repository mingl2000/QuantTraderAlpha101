# %%
import numpy as np
import pandas
import tushare

# %%
df = tushare.get_k_data("600519", start="1988-01-01")
df.to_csv("600519.csv")
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
# /home/zzz/anaconda3/envs/research/lib/python3.9/site-packages/tushare/stock/trading.py:706: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(_get_k_data(url, dataflag,
# /home/zzz/anaconda3/envs/research/lib/python3.9/site-packages/tushare/stock/trading.py:706: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(_get_k_data(url, dataflag,
# /home/zzz/anaconda3/envs/research/lib/python3.9/site-packages/tushare/stock/trading.py:706: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(_get_k_data(url, dataflag,
# ...

# %%
df = pandas.read_csv("600519.csv", index_col="date", parse_dates=["date"])[["open", "close", "high", "low"]]

# %%
df.loc["2017-12-15"]
# Out:
# open     580.469
# close    570.259
# high     584.419
# low      567.249
# Name: 2017-12-15 00:00:00, dtype: float64

# %%
df.resample("MS").last()
# Out:
#                 open     close      high       low
# date
# 2001-08-01  -112.565  -112.590  -112.481  -112.627
# 2001-09-01  -112.609  -112.575  -112.556  -112.680
# 2001-10-01  -112.947  -112.938  -112.931  -112.982
# 2001-11-01  -112.977  -112.886  -112.867  -112.982
# 2001-12-01  -112.472  -112.316  -112.183  -112.510
# ...              ...       ...       ...       ...
# 2022-03-01  1698.325  1697.325  1716.925  1687.125
# 2022-04-01  1814.325  1806.705  1827.325  1789.305
# 2022-05-01  1753.095  1782.355  1793.225  1745.305
# 2022-06-01  2000.000  2045.000  2077.000  1999.990
# 2022-07-01  1949.510  1944.650  1952.300  1931.000
#
# [252 rows x 4 columns]
